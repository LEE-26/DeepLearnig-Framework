# %% [markdown]
# # 구글 드라이브 마운트 및 로컬 디렉토리 설정

# %%
# 구글 드라이브 마운트
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd "/content/drive/MyDrive/project/colab_code/딥러닝프레임워크_기초"
# Out:
# /content/drive/MyDrive/project/colab_code/딥러닝프레임워크_기초

# %% [markdown]
# #  첫 번째 commit

# %%
# !git init
# Out:
# Initialized empty Git repository in /content/drive/My Drive/project/colab_code/딥러닝프레임워크_기초/.git/

# %%
# !git config --global user.email "tiffk79@gmail.com"
# !git config --global user.name "Leeyh"

# %%
# staging
# !git add .

# %%
# commit 
# !git commit -m "check 1"
# Out:
# [master (root-commit) 96a00b1] check 1
#  2 files changed, 2 insertions(+)
#  create mode 100644 TensorFlow_Keras_Tutorials.ipynb
#  create mode 100644 Upload to Github.ipynb

# %%
# 원격 저장소 주소 지정
# !git remote add origin "https://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@github.com/LEE-26/DeepLearnig-Framework.git"

# %%
# !git push -u origin master
# Out:
# Counting objects: 4, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 14.80 KiB | 2.47 MiB/s, done.
# Total 4 (delta 1), reused 0 (delta 0)
# remote: Resolving deltas: 100% (1/1), done.
# To https://github.com/LEE-26/DeepLearnig-Framework.git
#  * [new branch]      master -> master
# Branch 'master' set up to track remote branch 'master' from 'origin'.

# %% [markdown]
# # 두 번째 commit

# %%
! git commit -am "second commit"
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
! git push
